# %%
import urllib.request
import numpy as np
import pandas as pd

# %%
# Read two books, fast!

little_women_url =  urllib.request.urlopen('http://www.gutenberg.org/cache/epub/514/pg514.txt')
little_women_text = little_women_url.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d59e2e677761> in <module>()
#       1 # Read two books, fast!
#       2
# ----> 3 little_women_url =  urllib.request.urlopen('http://www.gutenberg.org/cache/epub/514/pg514.txt',r)
#       4 little_women_text = little_women_url.read()
#
# NameError: name 'r' is not defined

# %%
from urllib.request import urlopen
little_women_url= urlopen('http://www.gutenberg.org/cache/epub/514/pg514.txt') 
little_women_text = little_women_url.read() 
little_women_text = little_women_text.decode('utf-8')  # Decoding the binary data to text.

# %%
little_women_chapters = little_women_text.split('CHAPTER ')[1:]

# %%
little_women_chapters[0]
# Out:
# 'ONE\r\n\r\nPLAYING PILGRIMS\r\n\r\n"Christmas won\'t be Christmas without any presents," grumbled Jo, lying\r\non the rug.\r\n\r\n"It\'s so dreadful to be poor!" sighed Meg, looking down at her old\r\ndress.\r\n\r\n"I don\'t think it\'s fair for some girls to have plenty of pretty\r\nthings, and other girls nothing at all," added little Amy, with an\r\ninjured sniff.\r\n\r\n"We\'ve got Father and Mother, and each other," said Beth contentedly\r\nfrom her corner.\r\n\r\nThe four young faces on which the firelight shone brightened at the\r\ncheerful words, but darkened again as Jo said sadly, "We haven\'t got\r\nFather, and shall not have him for a long time." She didn\'t say\r\n"perhaps never," but each silently added it, thinking of Father far\r\naway, where the fighting was.\r\n\r\nNobody spoke for a minute; then Meg said in an altered tone, "You know\r\nthe reason Mother proposed not having any presents this Christmas was\r\nbecause it is going to be a hard winter for everyone; an
# ...

# %%
Table().with_columns(["Chapters", little_women_chapters])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-39cab22ce70a> in <module>()
# ----> 1 Table().with_columns(["Chapters", little_women_chapters])
#
# NameError: name 'Table' is not defined

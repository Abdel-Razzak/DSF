# %% [markdown]
# # Data Science Foundations: Overview
# ## Programming with Python

# %%
# %matplotlib inline

import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt 

np.random.seed(129)
data_1 = np.random.normal(62, 13, 60)
data_2 = np.random.normal(55, 9, 60)

combined_data = [data_1, data_2]

# figure instance
fig = plt.figure(1, figsize=(9, 6))

# axes instance
ax = fig.add_subplot(111)

# draw boxplot
bxp = ax.boxplot(combined_data)

# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix as spm

cars = pd.read_csv("http://www-bcf.usc.edu/~gareth/ISL/Auto.csv")

_ = spm(cars[['displacement', 'weight', 'mpg']], figsize=(14, 10))

# %%
cars.head()
# Out:
#    mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0   18          8           307        130    3504          12.0    70
# 1   15          8           350        165    3693          11.5    70
# 2   18          8           318        150    3436          11.0    70
# 3   16          8           304        150    3433          12.0    70
# 4   17          8           302        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
import statsmodels.formula.api as smf

# create a fitted model in one line
lm = smf.ols(formula='mpg ~ cylinders', data=cars).fit()

# print the coefficients
lm.params
# Out:
# Intercept    43.003226
# cylinders    -3.570134
# dtype: float64

# %%
lm.pvalues
# Out:
# Intercept    1.609258e-177
# cylinders     3.669162e-81
# dtype: float64

# %%
lm.conf_int()
# Out:
#                    0          1
# Intercept  41.363606  44.642846
# cylinders  -3.856938  -3.283330
